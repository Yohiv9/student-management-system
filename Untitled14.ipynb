# %% [markdown]
# <a href="https://colab.research.google.com/github/Yohiv9/student-management-system/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Add Two Numbers

# %%
a = 10
b = 20
print("Sum =", a + b)
# Out:
# Sum = 30

# %% [markdown]
# 2.Add Two Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Sum =", a + b)
# Out:
# Enter first number: 5
# Enter second number: 9
# Sum = 14

# %% [markdown]
# 3. Find Even or Odd

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 7
# Odd Number

# %% [markdown]
# 4. Find Largest of Two Numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Largest:", a)
else:
    print("Largest:", b)
# Out:
# Enter first number: 7
# Enter second number: 5
# Largest: 7

# %% [markdown]
# 5. Check Positive or Negative

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 5
# Positive

# %% [markdown]
# 6. Multiplication Table

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# 7. Sum of First N Natural Numbers

# %%
n = int(input("Enter n: "))
sum = 0

for i in range(1, n + 1):
    sum += i

print("Sum =", sum)
# Out:
# Enter n: 4
# Sum = 10

# %% [markdown]
# 8. Factorial of a Number

# %%
num = int(input("Enter a number: "))
fact = 1

for i in range(1, num + 1):
    fact *= i

print("Factorial =", fact)
# Out:
# Enter a number: 9
# Factorial = 362880

# %% [markdown]
# 9. Reverse a Number

# %%
num = int(input("Enter a number: "))
rev = 0

while num > 0:
    rev = rev * 10 + num % 10
    num //= 10

print("Reversed Number =", rev)
# Out:
# Enter a number: 12
# Reversed Number = 21

# %% [markdown]
# 10. Check Palindrome Number

# %%
num = int(input("Enter a number: "))
temp = num
rev = 0

while num > 0:
    rev = rev * 10 + num % 10
    num //= 10

if temp == rev:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a number: 13
# Not Palindrome

# %% [markdown]
# 11. Count Digits in a Number

# %%
num = int(input("Enter a number: "))
count = 0

while num > 0:
    count += 1
    num //= 10

print("Number of digits:", count)
# Out:
# Enter a number: 23
# Number of digits: 2

# %% [markdown]
# 12. Simple Calculator

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Enter first number: 35
# Enter second number: 47
# Addition: 82
# Subtraction: -12
# Multiplication: 1645
# Division: 0.7446808510638298

# %% [markdown]
# 13. Find Sum of Digits

# %%
num = int(input("Enter a number: "))
sum_digits = 0

while num > 0:
    sum_digits += num % 10
    num //= 10

print("Sum of digits:", sum_digits)
# Out:
# Enter a number: 45
# Sum of digits: 9

# %% [markdown]
# 14. Check Leap Year

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 21
# Not a Leap Year

# %% [markdown]
# 15. Check Prime Number

# %%
num = int(input("Enter a number: "))
flag = 0

if num <= 1:
    print("Not a Prime Number")
else:
    for i in range(2, num):
        if num % i == 0:
            flag = 1
            break

    if flag == 0:
        print("Prime Number")
    else:
        print("Not a Prime Number")
# Out:
# Enter a number: 56
# Not a Prime Number

# %% [markdown]
# 1. Hard Coding Variable

# %%
# 1. Hard Coding Variable

name = "yohv"
branch = "CSE"
semester = 6
cgpa = 8.5

print("Name:", name)
print("Branch:", branch)
print("Semester:", semester)
print("CGPA:", cgpa)
# Out:
# Name: yohv
# Branch: CSE
# Semester: 6
# CGPA: 8.5

# %% [markdown]
# 2. Keyboard Input

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
course = input("Enter your course: ")

print("Name:", name)
print("Age:", age)
print("Course:", course)
# Out:
# Enter your name: yohiv
# Enter your age: 21
# Enter your course: cse
# Name: yohiv
# Age: 21
# Course: cse
